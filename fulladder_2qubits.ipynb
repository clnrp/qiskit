# %%
from qiskit import QuantumRegister, ClassicalRegister, QuantumCircuit
from qiskit import BasicAer
from qiskit import execute
from qiskit.tools.visualization import plot_histogram, plot_state_city
from IBMQuantumExperience.IBMQuantumExperience import IBMQuantumExperience
from qiskit import IBMQ
from qiskit.providers.ibmq import least_busy
from qiskit.tools.monitor import job_monitor
import numpy as np
from math import *

# %%
q = QuantumRegister(4)
out = ClassicalRegister(2, "out")
qc = QuantumCircuit(q, out, name="fulladder")

qc.h(q[0]) # A
qc.h(q[1]) # B

qc.cx(q[0],q[2])
qc.cx(q[1],q[2])

qc.barrier() # conclui as operações antes de continuar
 
qc.ccx(q[0],q[1],q[3])

qc.measure(q[2], out[0])
qc.measure(q[3], out[1])

backend = BasicAer.get_backend('qasm_simulator')
result = execute(qc, backend, shots=1024).result()
counts  = result.get_counts(qc)
print(counts)
plot_histogram(counts)
# Out:
# {'01': 501, '00': 265, '10': 258}

# %%
qc.draw(output='mpl')

# %%
token = open("../ibm_token.txt","r").read().strip()
IBMQ.enable_account(token)
# Out:
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
shots = 1024

provider = IBMQ.get_provider()
print(provider.backends())
backend  = provider.get_backend('ibmq_belem')

job_exp = execute(qc, backend=backend, shots=shots)
job_monitor(job_exp)

# %%
result_exp = job_exp.result()
print(result_exp)

# %%
counts_exp = result_exp.get_counts(qc)
plot_histogram([counts_exp,counts])

# %%
jobID = job_exp.job_id()
print('JOB ID: {}'.format(jobID))

# %%
job_get=backend.retrieve_job('5ccb9eeb6443ec007394bef7')
rcounts = job_get.result().get_counts(qc)
plot_histogram(rcounts)

# %%
api = IBMQuantumExperience(token)
api.get_my_credits()
# Out:
# {'maxUserType': 15, 'promotional': 0, 'remaining': 12}

# %%
#api.get_last_codes()

# %%
api.get_jobs()
# Out:
# [{'backend': {'name': 'ibmq_qasm_simulator'},
#   'calibration': {},
#   'creationDate': '2019-05-04T03:28:47.063Z',
#   'deleted': False,
#   'endDate': '2019-05-04T03:28:47.318Z',
#   'id': '5ccd06ef9bfaab0074c5caa8',
#   'ip': {'city': 'Convento da Penha',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.158.48.174'},
#   'kind': 'q-object',
#   'maxCredits': 10,
#   'qObject': {'config': {'max_credits': 10,
#     'memory': False,
#     'memory_slots': 2,
#     'n_qubits': 4,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 2, 'n_qubits': 4},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q6[4];\ncreg out[1];\ncreg co[1];\nh q6[2];\nh q6[1];\nccx q6[1],q6[2],q6[3];\ncx q6[1],q6[2];\nccx q6[0],q6[2],q6[3];\ncx q6[0],q6[2];\nmeasure q6[2] -> out[0];\nmeasure q6[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q6', 4]],
#       'qubit_labels': [['q6', 0], ['q6', 1], ['q6', 2], ['q6', 3]]},
#      'instructions': [{'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [1, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [1, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [0, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [0, 2],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [3],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'qobj_id': '59a5cd62-18b4-4dd1-9b44-798bb5442311',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmq_qasm_simulator',
#    'backend_version': '0.2.0',
#    'date': '2019-05-04T03:28:47.278614',
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'job_id': '5ccd06ef9bfaab0074c5caa8',
#    'metadata': {'max_memory_mb': 257938,
#     'omp_enabled': True,
#     'parallel_experiments': 1,
#     'time_taken': 0.0018422150000000001},
#    'qobj_id': '59a5cd62-18b4-4dd1-9b44-798bb5442311',
#    'results': [{'data': {'counts': {'0x0': 239, '0x1': 543, '0x2': 242}},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q6[4];\ncreg out[1];\ncreg co[1];\nh q6[2];\nh q6[1];\nccx q6[1],q6[2],q6[3];\ncx q6[1],q6[2];\nccx q6[0],q6[2],q6[3];\ncx q6[0],q6[2];\nmeasure q6[2] -> out[0];\nmeasure q6[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q6', 4]],
#       'qubit_labels': [['q6', 0], ['q6', 1], ['q6', 2], ['q6', 3]]},
#      'metadata': {'method': 'statevector',
#       'parallel_shots': 1,
#       'parallel_state_update': 1},
#      'seed': 1151090360,
#      'shots': 1024,
#      'status': 'DONE',
#      'success': True,
#      'time_taken': 0.00177402}],
#    'status': 'COMPLETED',
#    'success': True,
#    'time_taken': 0.0018422150000000001},
#   'qasms': [{'executionId': '5ccd06ef9bfaab0074c5caa9',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 0.007988990051671863,
#   'usedCredits': 0,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'id': '5ae875670f020500393162b3', 'name': 'ibmqx4'},
#   'creationDate': '2019-05-04T03:20:40.804Z',
#   'deleted': False,
#   'id': '5ccd05084458f3006e21c2dc',
#   'ip': {'city': 'Convento da Penha',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.158.48.174'},
#   'kind': 'q-object',
#   'maxCredits': 3,
#   'qObject': {'config': {'max_credits': 3,
#     'memory': False,
#     'memory_slots': 5,
#     'n_qubits': 5,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 5, 'n_qubits': 5},
#      'header': {'clbit_labels': [['c0', 0],
#        ['c1', 0],
#        ['c2', 0],
#        ['c3', 0],
#        ['c4', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\ncreg c2[1];\ncreg c3[1];\ncreg c4[1];\ncx q[3],q[2];\nu3(pi/4,pi/2,3*pi/2) q[3];\nu2(0,pi) q[2];\nu3(1.57079632679490,0,6.28318530717959) q[1];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\nu2(0,pi) q[2];\ncx q[3],q[2];\nu2(pi/4,pi) q[3];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[4];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\nu2(0,pi) q[2];\ncx q[4],q[2];\nu2(-pi/4,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(pi/4,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\nu2(0,pi) q[2];\ncx q[3],q[2];\nu3(2.35619449019234,1.57079632679490,4.71238898038469) q[3];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu1(pi/4) q[2];\nu1(-pi/4) q[1];\ncx q[2],q[1];\nu3(1.57079632679490,-3.14159265358979,6.28318530717959) q[2];\ncx q[3],q[2];\nu2(0,pi) q[2];\nu2(0,pi) q[3];\ncx q[3],q[2];\nu2(0,pi) q[3];\nu2(0,pi) q[2];\ncx q[3],q[2];\nu2(0,pi) q[2];\nu1(3.14159265358979) q[1];\ncx q[2],q[1];\nu2(-pi/4,pi) q[2];\ncx q[3],q[2];\nu2(0,5*pi/4) q[2];\ncx q[2],q[1];\nu3(pi/4,pi/2,3*pi/2) q[2];\nu2(pi/4,pi) q[1];\nu2(0,pi) q[3];\ncx q[3],q[2];\nu2(0,pi) q[3];\nu2(0,pi) q[2];\ncx q[3],q[2];\ncx q[2],q[1];\nu1(pi/4) q[2];\nu1(-pi/4) q[1];\ncx q[2],q[1];\nu3(1.57079632679490,-3.14159265358979,6.28318530717959) q[2];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[1];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu3(3.14159265358979,0,10.2101761241668) q[3];\ncx q[3],q[2];\nu3(pi/4,pi/2,3*pi/2) q[3];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[3],q[2];\nu2(pi/4,pi) q[3];\nu2(0,pi) q[2];\ncx q[3],q[2];\nu2(0,pi) q[2];\nu2(0,pi) q[3];\ncx q[3],q[2];\nu2(0,pi) q[3];\nu2(0,pi) q[2];\ncx q[3],q[2];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(-pi/4,pi) q[2];\ncx q[3],q[2];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(pi/4,pi) q[1];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\ncx q[4],q[2];\nu1(pi/4) q[4];\nu1(-pi/4) q[2];\ncx q[4],q[2];\nu3(1.57079632679490,0,6.28318530717959) q[2];\nu3(1.57079632679490,-3.14159265358979,6.28318530717959) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi + 10.2101761241668) q[1];\ncx q[2],q[1];\nu1(-pi/4) q[1];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\ncx q[3],q[2];\nu2(0,5*pi/4) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\nu2(-pi/4,pi) q[2];\ncx q[3],q[2];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(0,pi) q[3];\nu2(0,pi) q[4];\ncx q[3],q[4];\nu2(pi/4,pi) q[1];\ncx q[2],q[1];\nu2(0,pi) q[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu2(0,pi) q[1];\ncx q[2],q[1];\ncx q[4],q[2];\nu1(-pi/4) q[2];\nu1(pi/4) q[4];\ncx q[4],q[2];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[4];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[2];\nu3(1.57079632679490,3.14159265358979,10.2101761241668) q[1];\nbarrier q[4],q[2],q[1];\nmeasure q[4] -> c0[0];\nmeasure q[2] -> c1[0];\nmeasure q[1] -> c2[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1], ['c2', 1], ['c3', 1], ['c4', 1]],
#       'memory_slots': 5,
#       'n_qubits': 5,
#       'name': 'grover2',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'instructions': [{'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [0.7853981633974483, 1.5707963267948966, 4.71238898038469],
#        'qubits': [3],
#        'texparams': ['\\frac{\\pi}{4}',
#         '\\frac{\\pi}{2}',
#         '\\frac{3 \\pi}{2}']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 0, 6.283185307179586],
#        'qubits': [1],
#        'texparams': ['1.5707963267949', '0', '6.28318530717959']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0.7853981633974483, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['\\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [4, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [-0.7853981633974483, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['- \\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0.7853981633974483, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['\\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [0.7853981633974483],
#        'qubits': [2],
#        'texparams': ['\\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'u1',
#        'params': [-0.7853981633974483],
#        'qubits': [1],
#        'texparams': ['- \\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [3.141592653589793],
#        'qubits': [1],
#        'texparams': ['3.14159265358979']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948963, -3.141592653589793, 6.283185307179586],
#        'qubits': [2],
#        'texparams': ['1.5707963267949',
#         '-3.14159265358979',
#         '6.28318530717959']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [2.356194490192345, 1.5707963267948968, 4.71238898038469],
#        'qubits': [3],
#        'texparams': ['2.35619449019234',
#         '1.5707963267949',
#         '4.71238898038469']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [-0.7853981633974483, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['- \\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.9269908169872414],
#        'qubits': [2],
#        'texparams': ['0', '\\frac{5 \\pi}{4}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0.7853981633974483, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['\\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [0.7853981633974483, 1.5707963267948966, 4.71238898038469],
#        'qubits': [2],
#        'texparams': ['\\frac{\\pi}{4}',
#         '\\frac{\\pi}{2}',
#         '\\frac{3 \\pi}{2}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [-0.7853981633974483],
#        'qubits': [1],
#        'texparams': ['- \\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'u1',
#        'params': [0.7853981633974483],
#        'qubits': [2],
#        'texparams': ['\\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '3.14159265358979']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948963, -3.141592653589793, 6.283185307179586],
#        'qubits': [2],
#        'texparams': ['1.5707963267949',
#         '-3.14159265358979',
#         '6.28318530717959']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [3.141592653589793, 0, 10.210176124166829],
#        'qubits': [3],
#        'texparams': ['3.14159265358979', '0', '10.2101761241668']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [0.7853981633974483, 1.5707963267948966, 4.71238898038469],
#        'qubits': [3],
#        'texparams': ['\\frac{\\pi}{4}',
#         '\\frac{\\pi}{2}',
#         '\\frac{3 \\pi}{2}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0.7853981633974483, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['\\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [-0.7853981633974483, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['- \\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0.7853981633974483, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['\\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 13.351768777756622],
#        'qubits': [1],
#        'texparams': ['0', '\\pi + 10.2101761241668']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [4, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [-0.7853981633974483],
#        'qubits': [2],
#        'texparams': ['- \\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'u1',
#        'params': [0.7853981633974483],
#        'qubits': [4],
#        'texparams': ['\\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [4, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948963, -3.141592653589793, 6.283185307179586],
#        'qubits': [4],
#        'texparams': ['1.5707963267949',
#         '-3.14159265358979',
#         '6.28318530717959']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 0, 6.283185307179586],
#        'qubits': [2],
#        'texparams': ['1.5707963267949', '0', '6.28318530717959']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [-0.7853981633974483],
#        'qubits': [1],
#        'texparams': ['- \\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.9269908169872414],
#        'qubits': [2],
#        'texparams': ['0', '\\frac{5 \\pi}{4}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [-0.7853981633974483, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['- \\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [3],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [3, 4],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0.7853981633974483, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['\\frac{\\pi}{4}', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 10.210176124166829],
#        'qubits': [1],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '10.2101761241668']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [4, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [0.7853981633974483],
#        'qubits': [4],
#        'texparams': ['\\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'u1',
#        'params': [-0.7853981633974483],
#        'qubits': [2],
#        'texparams': ['- \\frac{\\pi}{4}']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [4, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '3.14159265358979']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 3.141592653589793],
#        'qubits': [4],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '3.14159265358979']},
#       {'memory': [],
#        'name': 'barrier',
#        'params': [],
#        'qubits': [4, 2, 1],
#        'texparams': []},
#       {'memory': [2],
#        'name': 'measure',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [4],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmqx4'},
#    'qobj_id': '8c150515-5b3b-461d-9b54-6bc6e1ba7cc0',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qasms': [{'executionId': '5ccd050a4458f3006e21c2dd',
#     'status': 'WORKING_IN_PROGRESS'}],
#   'shots': 1024,
#   'status': 'RUNNING',
#   'usedCredits': 3,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'name': 'ibmq_qasm_simulator'},
#   'calibration': {},
#   'creationDate': '2019-05-04T03:01:03.465Z',
#   'deleted': False,
#   'endDate': '2019-05-04T03:01:04.210Z',
#   'id': '5ccd006fe151ae0075fbc55c',
#   'ip': {'city': 'Convento da Penha',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.158.48.174'},
#   'kind': 'q-object',
#   'maxCredits': 10,
#   'qObject': {'config': {'max_credits': 10,
#     'memory': False,
#     'memory_slots': 2,
#     'n_qubits': 4,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 2, 'n_qubits': 4},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q5[4];\ncreg out[1];\ncreg co[1];\nh q5[2];\nh q5[1];\nccx q5[1],q5[2],q5[3];\ncx q5[1],q5[2];\nccx q5[0],q5[2],q5[3];\ncx q5[0],q5[2];\nmeasure q5[2] -> out[0];\nmeasure q5[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q5', 4]],
#       'qubit_labels': [['q5', 0], ['q5', 1], ['q5', 2], ['q5', 3]]},
#      'instructions': [{'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [1, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [1, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [0, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [0, 2],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [3],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'qobj_id': 'b1dab1a3-041f-4089-95ce-7a223aedc6ac',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmq_qasm_simulator',
#    'backend_version': '0.2.0',
#    'date': '2019-05-04T03:01:04.165851',
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'job_id': '5ccd006fe151ae0075fbc55c',
#    'metadata': {'max_memory_mb': 257938,
#     'omp_enabled': True,
#     'parallel_experiments': 1,
#     'time_taken': 0.001769509},
#    'qobj_id': 'b1dab1a3-041f-4089-95ce-7a223aedc6ac',
#    'results': [{'data': {'counts': {'0x0': 240, '0x1': 502, '0x2': 282}},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q5[4];\ncreg out[1];\ncreg co[1];\nh q5[2];\nh q5[1];\nccx q5[1],q5[2],q5[3];\ncx q5[1],q5[2];\nccx q5[0],q5[2],q5[3];\ncx q5[0],q5[2];\nmeasure q5[2] -> out[0];\nmeasure q5[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q5', 4]],
#       'qubit_labels': [['q5', 0], ['q5', 1], ['q5', 2], ['q5', 3]]},
#      'metadata': {'method': 'statevector',
#       'parallel_shots': 1,
#       'parallel_state_update': 1},
#      'seed': 110610031,
#      'shots': 1024,
#      'status': 'DONE',
#      'success': True,
#      'time_taken': 0.001700403}],
#    'status': 'COMPLETED',
#    'success': True,
#    'time_taken': 0.001769509},
#   'qasms': [{'executionId': '5ccd006fe151ae0075fbc55d',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 0.007876822026446462,
#   'usedCredits': 0,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'name': 'ibmq_qasm_simulator'},
#   'calibration': {},
#   'creationDate': '2019-05-04T00:25:08.932Z',
#   'deleted': False,
#   'endDate': '2019-05-04T00:25:09.507Z',
#   'id': '5cccdbe4142c57007c238571',
#   'ip': {'city': 'Convento da Penha',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.158.48.174'},
#   'kind': 'q-object',
#   'maxCredits': 10,
#   'qObject': {'config': {'max_credits': 10,
#     'memory': False,
#     'memory_slots': 2,
#     'n_qubits': 4,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 2, 'n_qubits': 4},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q4[4];\ncreg out[1];\ncreg co[1];\nh q4[2];\nh q4[1];\nccx q4[1],q4[2],q4[3];\ncx q4[1],q4[2];\nccx q4[0],q4[2],q4[3];\ncx q4[0],q4[2];\nmeasure q4[2] -> out[0];\nmeasure q4[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q4', 4]],
#       'qubit_labels': [['q4', 0], ['q4', 1], ['q4', 2], ['q4', 3]]},
#      'instructions': [{'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [1, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [1, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [0, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [0, 2],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [3],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'qobj_id': '0c964605-7b94-4cb5-a725-5c23a864168f',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmq_qasm_simulator',
#    'backend_version': '0.2.0',
#    'date': '2019-05-04T00:25:09.468355',
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'job_id': '5cccdbe4142c57007c238571',
#    'metadata': {'max_memory_mb': 257938,
#     'omp_enabled': True,
#     'parallel_experiments': 1,
#     'time_taken': 0.001963891},
#    'qobj_id': '0c964605-7b94-4cb5-a725-5c23a864168f',
#    'results': [{'data': {'counts': {'0x0': 265, '0x1': 510, '0x2': 249}},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q4[4];\ncreg out[1];\ncreg co[1];\nh q4[2];\nh q4[1];\nccx q4[1],q4[2],q4[3];\ncx q4[1],q4[2];\nccx q4[0],q4[2],q4[3];\ncx q4[0],q4[2];\nmeasure q4[2] -> out[0];\nmeasure q4[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q4', 4]],
#       'qubit_labels': [['q4', 0], ['q4', 1], ['q4', 2], ['q4', 3]]},
#      'metadata': {'method': 'statevector',
#       'parallel_shots': 1,
#       'parallel_state_update': 1},
#      'seed': 61601085,
#      'shots': 1024,
#      'status': 'DONE',
#      'success': True,
#      'time_taken': 0.001895919}],
#    'status': 'COMPLETED',
#    'success': True,
#    'time_taken': 0.001963891},
#   'qasms': [{'executionId': '5cccdbe5142c57007c238572',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 0.008242128184065223,
#   'usedCredits': 0,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'name': 'ibmq_qasm_simulator'},
#   'calibration': {},
#   'creationDate': '2019-05-04T00:20:31.606Z',
#   'deleted': False,
#   'endDate': '2019-05-04T00:20:31.850Z',
#   'id': '5cccdacf1dbcd80074b7109a',
#   'ip': {'city': 'Convento da Penha',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.158.48.174'},
#   'kind': 'q-object',
#   'maxCredits': 10,
#   'qObject': {'config': {'max_credits': 10,
#     'memory': False,
#     'memory_slots': 2,
#     'n_qubits': 4,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 2, 'n_qubits': 4},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q3[4];\ncreg out[1];\ncreg co[1];\nh q3[2];\nh q3[1];\nccx q3[1],q3[2],q3[3];\ncx q3[1],q3[2];\nccx q3[0],q3[2],q3[3];\ncx q3[0],q3[2];\nmeasure q3[2] -> out[0];\nmeasure q3[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q3', 4]],
#       'qubit_labels': [['q3', 0], ['q3', 1], ['q3', 2], ['q3', 3]]},
#      'instructions': [{'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'h',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [1, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [1, 2],
#        'texparams': []},
#       {'memory': [],
#        'name': 'ccx',
#        'params': [],
#        'qubits': [0, 2, 3],
#        'texparams': []},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [0, 2],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [3],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'qobj_id': '9c5ec438-927b-4c21-b2a4-3d7738614626',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmq_qasm_simulator',
#    'backend_version': '0.2.0',
#    'date': '2019-05-04T00:20:31.797728',
#    'header': {'backend_name': 'ibmq_qasm_simulator'},
#    'job_id': '5cccdacf1dbcd80074b7109a',
#    'metadata': {'max_memory_mb': 257938,
#     'omp_enabled': True,
#     'parallel_experiments': 1,
#     'time_taken': 0.001670005},
#    'qobj_id': '9c5ec438-927b-4c21-b2a4-3d7738614626',
#    'results': [{'data': {'counts': {'0x0': 254, '0x1': 498, '0x2': 272}},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q3[4];\ncreg out[1];\ncreg co[1];\nh q3[2];\nh q3[1];\nccx q3[1],q3[2],q3[3];\ncx q3[1],q3[2];\nccx q3[0],q3[2],q3[3];\ncx q3[0],q3[2];\nmeasure q3[2] -> out[0];\nmeasure q3[3] -> co[0];\n',
#       'creg_sizes': [['out', 1], ['co', 1]],
#       'memory_slots': 2,
#       'n_qubits': 4,
#       'name': 'fulladder',
#       'qreg_sizes': [['q3', 4]],
#       'qubit_labels': [['q3', 0], ['q3', 1], ['q3', 2], ['q3', 3]]},
#      'metadata': {'method': 'statevector',
#       'parallel_shots': 1,
#       'parallel_state_update': 1},
#      'seed': 2832063976,
#      'shots': 1024,
#      'status': 'DONE',
#      'success': True,
#      'time_taken': 0.001598428}],
#    'status': 'COMPLETED',
#    'success': True,
#    'time_taken': 0.001670005},
#   'qasms': [{'executionId': '5cccdacf1dbcd80074b7109b',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 0.007395304040983319,
#   'usedCredits': 0,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'id': '5ae875670f020500393162b3', 'name': 'ibmqx4'},
#   'calibration': {'id': '5ccba10261cbf5006f350011', 'version': '4.0'},
#   'creationDate': '2019-05-03T01:52:43.631Z',
#   'deleted': False,
#   'endDate': '2019-05-03T02:13:47.204Z',
#   'id': '5ccb9eeb6443ec007394bef7',
#   'ip': {'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '186.212.161.33'},
#   'kind': 'q-object',
#   'maxCredits': 3,
#   'qObject': {'config': {'max_credits': 3,
#     'memory': False,
#     'memory_slots': 2,
#     'n_qubits': 5,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 2, 'n_qubits': 5},
#      'header': {'clbit_labels': [['out', 0], ['co', 0]],
# ...
#   'maxCredits': 3,
#   'qObject': {'config': {'max_credits': 3,
#     'memory': False,
#     'memory_slots': 3,
#     'n_qubits': 5,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 3, 'n_qubits': 5},
#      'header': {'clbit_labels': [['c0', 0], ['c1', 0], ['c2', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\ncreg c2[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu3(-pi,pi/2,3*pi/2) q[0];\nbarrier q[1],q[2],q[0];\nmeasure q[2] -> c2[0];\nmeasure q[1] -> c1[0];\nmeasure q[0] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1], ['c2', 1]],
#       'memory_slots': 3,
#       'n_qubits': 5,
#       'name': 'test1',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'instructions': [{'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [-3.141592653589793, 1.5707963267948966, 4.71238898038469],
#        'qubits': [0],
#        'texparams': ['- \\pi', '\\frac{\\pi}{2}', '\\frac{3 \\pi}{2}']},
#       {'memory': [],
#        'name': 'barrier',
#        'params': [],
#        'qubits': [1, 2, 0],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [0],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [2],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmqx4'},
#    'qobj_id': '79241c4f-f2c9-4ae3-bb52-22ec0c5d2258',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmqx4',
#    'backend_version': '1.3.0',
#    'date': '2019-04-30T16:13:00Z',
#    'execution_id': 'cae3a156-6b62-11e9-9f2c-305a3a7b72bd',
#    'header': {'backend_name': 'ibmqx4'},
#    'job_id': 'unknown',
#    'qobj_id': '79241c4f-f2c9-4ae3-bb52-22ec0c5d2258',
#    'results': [{'data': {'counts': {'0x0': 38,
#        '0x1': 265,
#        '0x2': 13,
#        '0x3': 149,
#        '0x4': 37,
#        '0x5': 297,
#        '0x6': 21,
#        '0x7': 204}},
#      'header': {'clbit_labels': [['c0', 0], ['c1', 0], ['c2', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\ncreg c2[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,pi) q[2];\nu3(-pi,pi/2,3*pi/2) q[0];\nbarrier q[1],q[2],q[0];\nmeasure q[2] -> c2[0];\nmeasure q[1] -> c1[0];\nmeasure q[0] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1], ['c2', 1]],
#       'memory_slots': 3,
#       'n_qubits': 5,
#       'name': 'test1',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'shots': 1024,
#      'success': True}],
#    'status': 'Successful completion',
#    'success': True},
#   'qasms': [{'executionId': '5cc8510aff378f006e48e1b1',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 17.934259176254272,
#   'usedCredits': 3,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'id': '5ae875670f020500393162b3', 'name': 'ibmqx4'},
#   'calibration': {'id': '5cc6caaf508cd50074b9aee8', 'version': '4.0'},
#   'creationDate': '2019-04-29T22:22:44.324Z',
#   'deleted': False,
#   'endDate': '2019-04-29T22:23:02.624Z',
#   'id': '5cc77934b2f4f00071ae4c05',
#   'ip': {'city': 'Vitória',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.133.149.171'},
#   'kind': 'q-object',
#   'maxCredits': 3,
#   'qObject': {'config': {'max_credits': 3,
#     'memory': False,
#     'memory_slots': 5,
#     'n_qubits': 5,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 5, 'n_qubits': 5},
#      'header': {'clbit_labels': [['c0', 0],
#        ['c1', 0],
#        ['c2', 0],
#        ['c3', 0],
#        ['c4', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\ncreg c2[1];\ncreg c3[1];\ncreg c4[1];\nu2(pi/2,-pi) q[2];\ncx q[2],q[1];\nu2(0,pi + 4.71238898038469) q[2];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[1];\ncx q[2],q[1];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[2];\nu1(3.14159265358979) q[1];\nbarrier q[2],q[1];\nmeasure q[2] -> c1[0];\nmeasure q[1] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1], ['c2', 1], ['c3', 1], ['c4', 1]],
#       'memory_slots': 5,
#       'n_qubits': 5,
#       'name': 'grover2',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'instructions': [{'memory': [],
#        'name': 'u2',
#        'params': [1.5707963267948966, -3.141592653589793],
#        'qubits': [2],
#        'texparams': ['\\frac{\\pi}{2}', '- \\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 7.853981633974483],
#        'qubits': [2],
#        'texparams': ['0', '\\pi + 4.71238898038469']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '3.14159265358979']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [3.141592653589793],
#        'qubits': [1],
#        'texparams': ['3.14159265358979']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '3.14159265358979']},
#       {'memory': [],
#        'name': 'barrier',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmqx4'},
#    'qobj_id': '257afe45-b956-414d-aaf7-f50d0218114e',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmqx4',
#    'backend_version': '1.3.0',
#    'date': '2019-04-29T22:23:01Z',
#    'execution_id': '51b87440-6acd-11e9-bec1-305a3a7b72bd',
#    'header': {'backend_name': 'ibmqx4'},
#    'job_id': 'unknown',
#    'qobj_id': '257afe45-b956-414d-aaf7-f50d0218114e',
#    'results': [{'data': {'counts': {'0x0': 85,
#        '0x1': 22,
#        '0x2': 869,
#        '0x3': 48}},
#      'header': {'clbit_labels': [['c0', 0],
#        ['c1', 0],
#        ['c2', 0],
#        ['c3', 0],
#        ['c4', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\ncreg c2[1];\ncreg c3[1];\ncreg c4[1];\nu2(pi/2,-pi) q[2];\ncx q[2],q[1];\nu2(0,pi + 4.71238898038469) q[2];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[1];\ncx q[2],q[1];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[2];\nu1(3.14159265358979) q[1];\nbarrier q[2],q[1];\nmeasure q[2] -> c1[0];\nmeasure q[1] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1], ['c2', 1], ['c3', 1], ['c4', 1]],
#       'memory_slots': 5,
#       'n_qubits': 5,
#       'name': 'grover2',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'shots': 1024,
#      'success': True}],
#    'status': 'Successful completion',
#    'success': True},
#   'qasms': [{'executionId': '5cc77934b2f4f00071ae4c06',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 16.860813856124878,
#   'usedCredits': 3,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'id': '5ae875670f020500393162b3', 'name': 'ibmqx4'},
#   'calibration': {'id': '5cc6caaf508cd50074b9aee8', 'version': '4.0'},
#   'creationDate': '2019-04-29T21:23:17.583Z',
#   'deleted': False,
#   'endDate': '2019-04-29T21:25:18.574Z',
#   'id': '5cc76b46caf6ec0077df6510',
#   'ip': {'city': 'Vitória',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.133.149.171'},
#   'kind': 'q-object',
#   'maxCredits': 3,
#   'qObject': {'config': {'max_credits': 3,
#     'memory': False,
#     'memory_slots': 5,
#     'n_qubits': 5,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 5, 'n_qubits': 5},
#      'header': {'clbit_labels': [['c0', 0],
#        ['c1', 0],
#        ['c2', 0],
#        ['c3', 0],
#        ['c4', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\ncreg c2[1];\ncreg c3[1];\ncreg c4[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,3.14159265358979 + pi) q[2];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[1];\ncx q[2],q[1];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[2];\nu1(3.14159265358979) q[1];\nbarrier q[1],q[2];\nmeasure q[2] -> c1[0];\nmeasure q[1] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1], ['c2', 1], ['c3', 1], ['c4', 1]],
#       'memory_slots': 5,
#       'n_qubits': 5,
#       'name': 'test1',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'instructions': [{'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 6.283185307179586],
#        'qubits': [2],
#        'texparams': ['0', '3.14159265358979 + \\pi']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '3.14159265358979']},
#       {'memory': [],
#        'name': 'cx',
#        'params': [],
#        'qubits': [2, 1],
#        'texparams': []},
#       {'memory': [],
#        'name': 'u1',
#        'params': [3.141592653589793],
#        'qubits': [1],
#        'texparams': ['3.14159265358979']},
#       {'memory': [],
#        'name': 'u3',
#        'params': [1.5707963267948968, 3.141592653589793, 3.141592653589793],
#        'qubits': [2],
#        'texparams': ['1.5707963267949',
#         '3.14159265358979',
#         '3.14159265358979']},
#       {'memory': [],
#        'name': 'barrier',
#        'params': [],
#        'qubits': [1, 2],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [2],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmqx4'},
#    'qobj_id': 'b817d86f-4de9-4bfa-95f7-6d87fde1183e',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmqx4',
#    'backend_version': '1.3.0',
#    'date': '2019-04-29T21:25:16Z',
#    'execution_id': '40df740a-6ac5-11e9-b8fb-305a3a7b72bd',
#    'header': {'backend_name': 'ibmqx4'},
#    'job_id': 'unknown',
#    'qobj_id': 'b817d86f-4de9-4bfa-95f7-6d87fde1183e',
#    'results': [{'data': {'counts': {'0x0': 36,
#        '0x1': 40,
#        '0x2': 264,
#        '0x3': 684}},
#      'header': {'clbit_labels': [['c0', 0],
#        ['c1', 0],
#        ['c2', 0],
#        ['c3', 0],
#        ['c4', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\ncreg c2[1];\ncreg c3[1];\ncreg c4[1];\nu2(0,pi) q[2];\ncx q[2],q[1];\nu2(0,3.14159265358979 + pi) q[2];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[1];\ncx q[2],q[1];\nu3(1.57079632679490,3.14159265358979,3.14159265358979) q[2];\nu1(3.14159265358979) q[1];\nbarrier q[1],q[2];\nmeasure q[2] -> c1[0];\nmeasure q[1] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1], ['c2', 1], ['c3', 1], ['c4', 1]],
#       'memory_slots': 5,
#       'n_qubits': 5,
#       'name': 'test1',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'shots': 1024,
#      'success': True}],
#    'status': 'Successful completion',
#    'success': True},
#   'qasms': [{'executionId': '5cc76b46caf6ec0077df6511',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 17.035242080688477,
#   'usedCredits': 3,
#   'userId': '5beeb33bd2e52a005360df70'},
#  {'backend': {'id': '5ae875670f020500393162b3', 'name': 'ibmqx4'},
#   'calibration': {'id': '5cc6caaf508cd50074b9aee8', 'version': '4.0'},
#   'creationDate': '2019-04-29T20:45:10.944Z',
#   'deleted': False,
#   'endDate': '2019-04-29T20:48:31.791Z',
#   'id': '5cc76257f610f5006cd798bd',
#   'ip': {'city': 'Vitória',
#    'continent': 'South America',
#    'country': 'Brazil',
#    'ip': '177.133.149.171'},
#   'kind': 'q-object',
#   'maxCredits': 3,
#   'qObject': {'config': {'max_credits': 3,
#     'memory': False,
#     'memory_slots': 2,
#     'n_qubits': 5,
#     'shots': 1024},
#    'experiments': [{'config': {'memory_slots': 2, 'n_qubits': 5},
#      'header': {'clbit_labels': [['c0', 0], ['c1', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\nu2(0,pi) q[1];\nu2(0,pi) q[0];\nbarrier q[0],q[1];\nmeasure q[1] -> c1[0];\nmeasure q[0] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1]],
#       'memory_slots': 2,
#       'n_qubits': 5,
#       'name': 'test1',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'instructions': [{'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [1],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'u2',
#        'params': [0, 3.141592653589793],
#        'qubits': [0],
#        'texparams': ['0', '\\pi']},
#       {'memory': [],
#        'name': 'barrier',
#        'params': [],
#        'qubits': [0, 1],
#        'texparams': []},
#       {'memory': [1],
#        'name': 'measure',
#        'params': [],
#        'qubits': [1],
#        'texparams': []},
#       {'memory': [0],
#        'name': 'measure',
#        'params': [],
#        'qubits': [0],
#        'texparams': []}]}],
#    'header': {'backend_name': 'ibmqx4'},
#    'qobj_id': '7315a129-a1f3-4eb2-9957-bc6f752da46f',
#    'schema_version': '1.0.0',
#    'type': 'QASM'},
#   'qObjectResult': {'backend_name': 'ibmqx4',
#    'backend_version': '1.3.0',
#    'date': '2019-04-29T20:48:30Z',
#    'execution_id': '1da8f3ee-6ac0-11e9-bc9e-305a3a7b72bd',
#    'header': {'backend_name': 'ibmqx4'},
#    'job_id': 'unknown',
#    'qobj_id': '7315a129-a1f3-4eb2-9957-bc6f752da46f',
#    'results': [{'data': {'counts': {'0x0': 385,
#        '0x1': 320,
#        '0x2': 186,
#        '0x3': 133}},
#      'header': {'clbit_labels': [['c0', 0], ['c1', 0]],
#       'compiled_circuit_qasm': 'OPENQASM 2.0;\ninclude "qelib1.inc";\nqreg q[5];\ncreg c0[1];\ncreg c1[1];\nu2(0,pi) q[1];\nu2(0,pi) q[0];\nbarrier q[0],q[1];\nmeasure q[1] -> c1[0];\nmeasure q[0] -> c0[0];\n',
#       'creg_sizes': [['c0', 1], ['c1', 1]],
#       'memory_slots': 2,
#       'n_qubits': 5,
#       'name': 'test1',
#       'qreg_sizes': [['q', 5]],
#       'qubit_labels': [['q', 0], ['q', 1], ['q', 2], ['q', 3], ['q', 4]]},
#      'shots': 1024,
#      'success': True}],
#    'status': 'Successful completion',
#    'success': True},
#   'qasms': [{'executionId': '5cc76257f610f5006cd798be',
#     'result': None,
#     'status': 'DONE'}],
#   'shots': 1024,
#   'status': 'COMPLETED',
#   'totalTimeDevice': 16.970738887786865,
#   'usedCredits': 3,
#   'userId': '5beeb33bd2e52a005360df70'}]
